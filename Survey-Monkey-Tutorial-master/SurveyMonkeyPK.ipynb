# %%
# Day in the Life of a Data Analyst - SurveyMonkey Data Transformation
# https://www.youtube.com/watch?v=pKvWD0f18Pc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
pwd = os.getcwd()

# %%
pwd
# Out:
# 'C:\\Users\\prafulla.kamble\\Downloads\\0PRK\\ML\\Pandas\\Survey-Monkey-Tutorial-master\\Survey-Monkey-Tutorial-master'

# %%
dataset = pd.read_excel(pwd + "//Data - Survey Monkey Output Edited.xlsx",sheet_name="Edited_Data")
dataset.head()
# Out:
#    Respondent ID          Start Date            End Date  Email Address  \
# 0     5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1     2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2     4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3     5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4     3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
#
#    First Name  Last Name  Custom Data 1  \
# 0         NaN        NaN            NaN
# 1         NaN        NaN            NaN
# 2         NaN        NaN            NaN
# 3         NaN        NaN            NaN
# 4         NaN        NaN            NaN
#
#   Identify which division you work in. - Response  \
# 0                                  Infrastructure
# 1                                         Finance
# 2                                  Infrastructure
# 3                                  Infrastructure
# 4                                 Port Operations
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level? - Response  ...  \
# 0                                              Staff                     ...
# 1                                              Staff                     ...
# 2                                    Department Lead                     ...
# 3                                            Manager                     ...
# 4                                            Manager                     ...
#
#   Question 29 - Response 8 Question 29 - Response 9 Question 29 - Response 10  \
# 0                      NaN                 Answer 8                  Answer 8
# 1                      NaN                 Answer 5                       NaN
# 2                      NaN                      NaN                  Answer 4
# 3                 Answer 2                 Answer 5                  Answer 7
# 4                      NaN                 Answer 5                  Answer 4
#
#   Question 29 - Response 11 Question 29 - Response 12  \
# 0                  Answer 4                       NaN
# 1                       NaN                  Answer 2
# 2                  Answer 4                  Answer 6
# 3                       NaN                  Answer 6
# 4                  Answer 4                  Answer 7
#
#   Question 29 - Response 13 Question 29 - Response 14  \
# 0                       NaN                  Answer 5
# 1                       NaN                  Answer 5
# 2                       NaN                  Answer 6
# 3                       NaN                  Answer 7
# 4                  Answer 7                       NaN
#
#   Question 30 - Response 1 Question 30 - Response 2 Question 30 - Response 3
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                 Answer 1
# 2                      NaN                 Answer 1                      NaN
# 3                 Answer 7                 Answer 1                 Answer 6
# 4                 Answer 7                      NaN                 Answer 8
#
# [5 rows x 100 columns]

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 193         NaN        NaN            NaN
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
#
#     Identify which division you work in. - Response  \
# 0                                    Infrastructure
# 1                                           Finance
# 2                                    Infrastructure
# 3                                    Infrastructure
# 4                                   Port Operations
# ..                                              ...
# 193                                  Infrastructure
# 194                                         Finance
# 195                                 Port Operations
# 196                                  Infrastructure
# 197                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
#
#     Which of the following best describes your position level? - Response  \
# 0                                                Staff
# 1                                                Staff
# 2                                      Department Lead
# 3                                              Manager
# 4                                              Manager
# ..                                                 ...
# 193                                    Department Lead
# 194                                              Staff
# 195                                              Staff
# 196                                            Manager
# 197                                              Staff
#
#      ... Question 29 - Response 8 Question 29 - Response 9  \
# 0    ...                      NaN                 Answer 8
# 1    ...                      NaN                 Answer 5
# 2    ...                      NaN                      NaN
# 3    ...                 Answer 2                 Answer 5
# 4    ...                      NaN                 Answer 5
# ..   ...                      ...                      ...
# 193  ...                 Answer 1                 Answer 1
# 194  ...                 Answer 5                      NaN
# 195  ...                      NaN                 Answer 7
# 196  ...                 Answer 2                      NaN
# 197  ...                 Answer 3                      NaN
#
#     Question 29 - Response 10 Question 29 - Response 11  \
# 0                    Answer 8                  Answer 4
# 1                         NaN                       NaN
# 2                    Answer 4                  Answer 4
# 3                    Answer 7                       NaN
# 4                    Answer 4                  Answer 4
# ..                        ...                       ...
# 193                  Answer 3                  Answer 6
# 194                  Answer 5                       NaN
# 195                       NaN                       NaN
# 196                  Answer 3                  Answer 5
# 197                  Answer 7                       NaN
#
#     Question 29 - Response 12 Question 29 - Response 13  \
# 0                         NaN                       NaN
# 1                    Answer 2                       NaN
# 2                    Answer 6                       NaN
# 3                    Answer 6                       NaN
# 4                    Answer 7                  Answer 7
# ..                        ...                       ...
# 193                  Answer 6                  Answer 8
# 194                       NaN                  Answer 2
# 195                       NaN                       NaN
# 196                       NaN                  Answer 8
# 197                       NaN                       NaN
#
#     Question 29 - Response 14 Question 30 - Response 1  \
# 0                    Answer 5                      NaN
# 1                    Answer 5                      NaN
# 2                    Answer 6                      NaN
# 3                    Answer 7                 Answer 7
# 4                         NaN                 Answer 7
# ..                        ...                      ...
# 193                       NaN                      NaN
# 194                       NaN                      NaN
# 195                       NaN                      NaN
# 196                  Answer 3                 Answer 3
# 197                       NaN                 Answer 3
#
#     Question 30 - Response 2 Question 30 - Response 3
# 0                        NaN                      NaN
# 1                        NaN                 Answer 1
# 2                   Answer 1                      NaN
# 3                   Answer 1                 Answer 6
# 4                        NaN                 Answer 8
# ..                       ...                      ...
# 193                      NaN                 Answer 8
# 194                      NaN                 Answer 6
# 195                 Answer 3                      NaN
# 196                      NaN                      NaN
# 197                      NaN                      NaN
#
# [198 rows x 100 columns]

# %%
dataset_modified.columns
# Out:
# Index(['Respondent ID', 'Start Date', 'End Date', 'Email Address',
#        'First Name', 'Last Name', 'Custom Data 1',
#        'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question 1 - Response', 'Question 2 - Response',
#        'Question 3 - Open-Ended Response', 'Question 4 - Response',
#        'Question 4 - Other (please specify)', 'Question 5 - Response 1',
#        'Question 5 - Response 2', 'Question 5 - Response 3',
#        'Question 5 - Response 4', 'Question 5 - Response 5',
#        'Question 5 - Response 6', 'Question 6 - Response 1',
#        'Question 6 - Response 2', 'Question 6 - Response 3',
#        'Question 6 - Response 4', 'Question 6 - Response 5',
#        'Question 6 - Response 6', 'Question 7 - Response 1',
#        'Question 7 - Unscheduled', 'Question 8 - Response 1',
#        'Question 8 - Response 2', 'Question 8 - Response 3',
#        'Question 8 - Response 4', 'Question 9 - Response 1',
#        'Question 9 - Response 2', 'Question 9 - Response 3',
#        'Question 9 - Response 4', 'Question 10 - Response 1',
#        'Question 10 - Response 2', 'Question 10 - Response 3',
#        'Question 10 - Response 4', 'Question 10 - Response 5',
#        'Question 11 - Reponse 1', 'Question 11 - Response 2',
#        'Question 12 - Response', 'Question 13 - Response',
#        'Question 14 - Response', 'Question 15 - Response',
#        'Question 16 - Response', 'Question 17 - Response',
#        'Question 18 - Response', 'Question 19 - Response',
#        'Question 19 - Other (please specify)', 'Question 20 - Response',
#        'Question 21 - Response', 'Question 22 - Reponse 1',
#        'Question 22 - Reponse 2', 'Question 23 - Response',
#        'Question 24 - Response 1', 'Question 24 - Response 2',
#        'Question 24 - Response 3', 'Question 24 - Response 4',
#        'Question 24 - Response 5', 'Question 25 - Response 1',
#        'Question 25 - Response 2', 'Question 25 - Response 3',
#        'Question 25 - Response 4', 'Question 25 - Response 5',
#        'Question 25 - Response 6', 'Question 25 - Response 7',
#        'Question 25 - Response 8', 'Question 25 - Response 9',
#        'Question 26 - Response 1', 'Question 26 - Response 2',
#        'Question 26 - Response 3', 'Question 26 - Response 4',
#        'Question 27 - Response 1', 'Question 27 - Response 2',
#        'Question 28 - Response', 'Question 29 - Response 1',
#        'Question 29 - Response 2', 'Question 29 - Response 3',
#        'Question 29 - Response 4', 'Question 29 - Response 5',
#        'Question 29 - Response 6', 'Question 29 - Response 7',
#        'Question 29 - Response 8', 'Question 29 - Response 9',
#        'Question 29 - Response 10', 'Question 29 - Response 11',
#        'Question 29 - Response 12', 'Question 29 - Response 13',
#        'Question 29 - Response 14', 'Question 30 - Response 1',
#        'Question 30 - Response 2', 'Question 30 - Response 3'],
#       dtype='object')

# %%
drop_columns = ['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name']

# %%
dataset_modified = dataset_modified.drop(columns=drop_columns)
dataset_modified
# Out:
#      Respondent ID  Custom Data 1  \
# 0       5379192392            NaN
# 1       2658722536            NaN
# 2       4044163394            NaN
# 3       5535865599            NaN
# 4       3356802928            NaN
# ..             ...            ...
# 193     7940065082            NaN
# 194     5157705612            NaN
# 195     9920755555            NaN
# 196     6638341389            NaN
# 197     8114622230            NaN
#
#     Identify which division you work in. - Response  \
# 0                                    Infrastructure
# 1                                           Finance
# 2                                    Infrastructure
# 3                                    Infrastructure
# 4                                   Port Operations
# ..                                              ...
# 193                                  Infrastructure
# 194                                         Finance
# 195                                 Port Operations
# 196                                  Infrastructure
# 197                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
#
#     Which of the following best describes your position level? - Response  \
# 0                                                Staff
# 1                                                Staff
# 2                                      Department Lead
# 3                                              Manager
# 4                                              Manager
# ..                                                 ...
# 193                                    Department Lead
# 194                                              Staff
# 195                                              Staff
# 196                                            Manager
# 197                                              Staff
#
#     Which generation are you apart of? - Response  \
# 0           Generation X (born between 1965-1980)
# 1                                             NaN
# 2           Generation X (born between 1965-1980)
# 3             Millennial (born between 1981-2000)
# 4           Generation X (born between 1965-1980)
# ..                                            ...
# 193          Baby Boomer (born between 1946-1964)
# 194           Millennial (born between 1981-2000)
# 195           Millennial (born between 1981-2000)
# 196           Millennial (born between 1981-2000)
# 197                          Prefer not to answer
#
#     Please select the gender in which you identify. - Response  \
# 0                                                 Male
# 1                                                  NaN
# 2                                                 Male
# 3                                           Non-Binary
# 4                                               Female
# ..                                                 ...
# 193                                               Male
# 194                                             Female
# 195                                             Female
# 196                                             Female
# 197                                               Male
#
#     Which duration range best aligns with your tenure at your company? - Response  \
# 0                                            0-2 years
# 1                                            10+ years
# 2                                            3-5 years
# 3                                           5-10 years
# 4                                            10+ years
# ..                                                 ...
# 193                                          10+ years
# 194                                         5-10 years
# 195                                          3-5 years
# 196                                          3-5 years
# 197                                         5-10 years
#
#     Which of the following best describes your employment type? - Response  \
# 0                                   Full time Employee
# 1                                   Full time Employee
# 2                                   Full time Employee
# 3                                   Full time Employee
# 4                                   Full time Employee
# ..                                                 ...
# 193                                 Full time Employee
# 194                                 Full time Employee
# 195                                 Full time Employee
# 196                                 Full time Employee
# 197                                 Full time Employee
#
#     Question 1 - Response  ... Question 29 - Response 8  \
# 0                     NaN  ...                      NaN
# 1                Answer 4  ...                      NaN
# 2                Answer 5  ...                      NaN
# 3                Answer 1  ...                 Answer 2
# 4                     NaN  ...                      NaN
# ..                    ...  ...                      ...
# 193              Answer 3  ...                 Answer 1
# 194                   NaN  ...                 Answer 5
# 195                   NaN  ...                      NaN
# 196                   NaN  ...                 Answer 2
# 197                   NaN  ...                 Answer 3
#
#     Question 29 - Response 9 Question 29 - Response 10  \
# 0                   Answer 8                  Answer 8
# 1                   Answer 5                       NaN
# 2                        NaN                  Answer 4
# 3                   Answer 5                  Answer 7
# 4                   Answer 5                  Answer 4
# ..                       ...                       ...
# 193                 Answer 1                  Answer 3
# 194                      NaN                  Answer 5
# 195                 Answer 7                       NaN
# 196                      NaN                  Answer 3
# 197                      NaN                  Answer 7
#
#     Question 29 - Response 11 Question 29 - Response 12  \
# 0                    Answer 4                       NaN
# 1                         NaN                  Answer 2
# 2                    Answer 4                  Answer 6
# 3                         NaN                  Answer 6
# 4                    Answer 4                  Answer 7
# ..                        ...                       ...
# 193                  Answer 6                  Answer 6
# 194                       NaN                       NaN
# 195                       NaN                       NaN
# 196                  Answer 5                       NaN
# 197                       NaN                       NaN
#
#     Question 29 - Response 13 Question 29 - Response 14  \
# 0                         NaN                  Answer 5
# 1                         NaN                  Answer 5
# 2                         NaN                  Answer 6
# 3                         NaN                  Answer 7
# 4                    Answer 7                       NaN
# ..                        ...                       ...
# 193                  Answer 8                       NaN
# 194                  Answer 2                       NaN
# 195                       NaN                       NaN
# 196                  Answer 8                  Answer 3
# 197                       NaN                       NaN
#
#     Question 30 - Response 1 Question 30 - Response 2 Question 30 - Response 3
# 0                        NaN                      NaN                      NaN
# 1                        NaN                      NaN                 Answer 1
# 2                        NaN                 Answer 1                      NaN
# 3                   Answer 7                 Answer 1                 Answer 6
# 4                   Answer 7                      NaN                 Answer 8
# ..                       ...                      ...                      ...
# 193                      NaN                      NaN                 Answer 8
# 194                      NaN                      NaN                 Answer 6
# 195                      NaN                 Answer 3                      NaN
# 196                 Answer 3                      NaN                      NaN
# 197                 Answer 3                      NaN                      NaN
#
# [198 rows x 95 columns]

# %%
## Unpivoting data/Melting data/ making loong data

# %%
id_vars = list(dataset_modified.columns[:8])
id_vars
# Out:
# ['Respondent ID',
#  'Custom Data 1',
#  'Identify which division you work in. - Response',
#  'Identify which division you work in. - Other (please specify)',
#  'Which of the following best describes your position level? - Response',
#  'Which generation are you apart of? - Response',
#  'Please select the gender in which you identify. - Response',
#  'Which duration range best aligns with your tenure at your company? - Response']

# %%
value_vars = list(dataset_modified.columns[8:])
value_vars
# Out:
# ['Which of the following best describes your employment type? - Response',
#  'Question 1 - Response',
#  'Question 2 - Response',
#  'Question 3 - Open-Ended Response',
#  'Question 4 - Response',
#  'Question 4 - Other (please specify)',
#  'Question 5 - Response 1',
#  'Question 5 - Response 2',
#  'Question 5 - Response 3',
#  'Question 5 - Response 4',
#  'Question 5 - Response 5',
#  'Question 5 - Response 6',
#  'Question 6 - Response 1',
#  'Question 6 - Response 2',
#  'Question 6 - Response 3',
#  'Question 6 - Response 4',
#  'Question 6 - Response 5',
#  'Question 6 - Response 6',
#  'Question 7 - Response 1',
#  'Question 7 - Unscheduled',
#  'Question 8 - Response 1',
#  'Question 8 - Response 2',
#  'Question 8 - Response 3',
#  'Question 8 - Response 4',
#  'Question 9 - Response 1',
#  'Question 9 - Response 2',
#  'Question 9 - Response 3',
#  'Question 9 - Response 4',
#  'Question 10 - Response 1',
#  'Question 10 - Response 2',
#  'Question 10 - Response 3',
#  'Question 10 - Response 4',
#  'Question 10 - Response 5',
#  'Question 11 - Reponse 1',
#  'Question 11 - Response 2',
#  'Question 12 - Response',
#  'Question 13 - Response',
#  'Question 14 - Response',
#  'Question 15 - Response',
#  'Question 16 - Response',
#  'Question 17 - Response',
#  'Question 18 - Response',
#  'Question 19 - Response',
#  'Question 19 - Other (please specify)',
#  'Question 20 - Response',
#  'Question 21 - Response',
#  'Question 22 - Reponse 1',
#  'Question 22 - Reponse 2',
#  'Question 23 - Response',
#  'Question 24 - Response 1',
#  'Question 24 - Response 2',
#  'Question 24 - Response 3',
#  'Question 24 - Response 4',
#  'Question 24 - Response 5',
#  'Question 25 - Response 1',
#  'Question 25 - Response 2',
#  'Question 25 - Response 3',
#  'Question 25 - Response 4',
#  'Question 25 - Response 5',
#  'Question 25 - Response 6',
#  'Question 25 - Response 7',
#  'Question 25 - Response 8',
#  'Question 25 - Response 9',
#  'Question 26 - Response 1',
#  'Question 26 - Response 2',
#  'Question 26 - Response 3',
#  'Question 26 - Response 4',
#  'Question 27 - Response 1',
#  'Question 27 - Response 2',
#  'Question 28 - Response',
#  'Question 29 - Response 1',
#  'Question 29 - Response 2',
#  'Question 29 - Response 3',
#  'Question 29 - Response 4',
#  'Question 29 - Response 5',
#  'Question 29 - Response 6',
#  'Question 29 - Response 7',
#  'Question 29 - Response 8',
#  'Question 29 - Response 9',
#  'Question 29 - Response 10',
#  'Question 29 - Response 11',
#  'Question 29 - Response 12',
#  'Question 29 - Response 13',
#  'Question 29 - Response 14',
#  'Question 30 - Response 1',
#  'Question 30 - Response 2',
#  'Question 30 - Response 3']

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars,value_vars=value_vars,var_name="Question + Subquestion",value_name="Answer")
dataset_melted
# Out:
#        Respondent ID  Custom Data 1  \
# 0         5379192392            NaN
# 1         2658722536            NaN
# 2         4044163394            NaN
# 3         5535865599            NaN
# 4         3356802928            NaN
# ...              ...            ...
# 17221     7940065082            NaN
# 17222     5157705612            NaN
# 17223     9920755555            NaN
# 17224     6638341389            NaN
# 17225     8114622230            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 17221                                  Infrastructure
# 17222                                         Finance
# 17223                                 Port Operations
# 17224                                  Infrastructure
# 17225                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17221                                                NaN
# 17222                                                NaN
# 17223                                                NaN
# 17224                                                NaN
# 17225                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17221                                    Department Lead
# 17222                                              Staff
# 17223                                              Staff
# 17224                                            Manager
# 17225                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17221          Baby Boomer (born between 1946-1964)
# 17222           Millennial (born between 1981-2000)
# 17223           Millennial (born between 1981-2000)
# 17224           Millennial (born between 1981-2000)
# 17225                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17221                                               Male
# 17222                                             Female
# 17223                                             Female
# 17224                                             Female
# 17225                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17221                                          10+ years
# 17222                                         5-10 years
# 17223                                          3-5 years
# 17224                                          3-5 years
# 17225                                         5-10 years
#
#                                   Question + Subquestion              Answer
# 0      Which of the following best describes your emp...  Full time Employee
# 1      Which of the following best describes your emp...  Full time Employee
# 2      Which of the following best describes your emp...  Full time Employee
# 3      Which of the following best describes your emp...  Full time Employee
# 4      Which of the following best describes your emp...  Full time Employee
# ...                                                  ...                 ...
# 17221                           Question 30 - Response 3            Answer 8
# 17222                           Question 30 - Response 3            Answer 6
# 17223                           Question 30 - Response 3                 NaN
# 17224                           Question 30 - Response 3                 NaN
# 17225                           Question 30 - Response 3                 NaN
#
# [17226 rows x 10 columns]

# %%
questions_import = pd.read_excel(pwd + "//Data - Survey Monkey Output Edited.xlsx",sheet_name='Question')
questions_import
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions = questions_import.copy()
questions
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions.drop(columns=["Raw Question","Raw Subquestion","Subquestion"],inplace=True)

# %%
questions.dropna(inplace=True)

# %%
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
## JOIN

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how="left", left_on="Question + Subquestion", right_on="Question + Subquestion")
print("Original dataset",len(dataset_melted))
print("dataset_melted: ", len(dataset_merged))
print("====================================================")
dataset_merged
# Out:
# Original dataset 17226
# dataset_melted:  17226
# ====================================================
#        Respondent ID  Custom Data 1  \
# 0         5379192392            NaN
# 1         2658722536            NaN
# 2         4044163394            NaN
# 3         5535865599            NaN
# 4         3356802928            NaN
# ...              ...            ...
# 17221     7940065082            NaN
# 17222     5157705612            NaN
# 17223     9920755555            NaN
# 17224     6638341389            NaN
# 17225     8114622230            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 17221                                  Infrastructure
# 17222                                         Finance
# 17223                                 Port Operations
# 17224                                  Infrastructure
# 17225                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17221                                                NaN
# 17222                                                NaN
# 17223                                                NaN
# 17224                                                NaN
# 17225                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17221                                    Department Lead
# 17222                                              Staff
# 17223                                              Staff
# 17224                                            Manager
# 17225                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17221          Baby Boomer (born between 1946-1964)
# 17222           Millennial (born between 1981-2000)
# 17223           Millennial (born between 1981-2000)
# 17224           Millennial (born between 1981-2000)
# 17225                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17221                                               Male
# 17222                                             Female
# 17223                                             Female
# 17224                                             Female
# 17225                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17221                                          10+ years
# 17222                                         5-10 years
# 17223                                          3-5 years
# 17224                                          3-5 years
# 17225                                         5-10 years
#
#                                   Question + Subquestion              Answer  \
# 0      Which of the following best describes your emp...  Full time Employee
# 1      Which of the following best describes your emp...  Full time Employee
# 2      Which of the following best describes your emp...  Full time Employee
# 3      Which of the following best describes your emp...  Full time Employee
# 4      Which of the following best describes your emp...  Full time Employee
# ...                                                  ...                 ...
# 17221                           Question 30 - Response 3            Answer 8
# 17222                           Question 30 - Response 3            Answer 6
# 17223                           Question 30 - Response 3                 NaN
# 17224                           Question 30 - Response 3                 NaN
# 17225                           Question 30 - Response 3                 NaN
#
#                                                 Question
# 0      Which of the following best describes your emp...
# 1      Which of the following best describes your emp...
# 2      Which of the following best describes your emp...
# 3      Which of the following best describes your emp...
# 4      Which of the following best describes your emp...
# ...                                                  ...
# 17221                                        Question 30
# 17222                                        Question 30
# 17223                                        Question 30
# 17224                                        Question 30
# 17225                                        Question 30
#
# [17226 rows x 11 columns]

# %%
dataset_merged.groupby("Question")["Answer"].count().reset_index
# Out:
# <bound method Series.reset_index of Question
# Question 1                                                      119
# Question 10                                                     585
# Question 11                                                     239
# Question 12                                                     114
# Question 13                                                     108
# Question 14                                                     105
# Question 15                                                     114
# Question 16                                                     117
# Question 17                                                     135
# Question 18                                                     109
# Question 19                                                     226
# Question 2                                                      118
# Question 20                                                     105
# Question 21                                                     127
# Question 22                                                     214
# Question 23                                                     120
# Question 24                                                     544
# Question 25                                                     970
# Question 26                                                     436
# Question 27                                                     211
# Question 28                                                     119
# Question 29                                                    1584
# Question 3                                                      117
# Question 30                                                     332
# Question 4                                                      220
# Question 5                                                      676
# Question 6                                                      664
# Question 7                                                      237
# Question 8                                                      446
# Question 9                                                      453
# Which of the following best describes your employment type?     198
# Name: Answer, dtype: int64>

# %%
#

# %%
respondents = dataset_merged[dataset_merged['Answer'].notna()]
respondents= respondents.groupby("Question")["Respondent ID"].nunique().reset_index()
respondents.rename(columns={"Respondent ID": "Respondents"},inplace=True)
respondents
# Out:
#                                              Question  Respondents
# 0                                          Question 1          119
# 1                                         Question 10          198
# 2                                         Question 11          164
# 3                                         Question 12          114
# 4                                         Question 13          108
# 5                                         Question 14          105
# 6                                         Question 15          114
# 7                                         Question 16          117
# 8                                         Question 17          135
# 9                                         Question 18          109
# 10                                        Question 19          157
# 11                                         Question 2          118
# 12                                        Question 20          105
# 13                                        Question 21          127
# 14                                        Question 22          160
# 15                                        Question 23          120
# 16                                        Question 24          195
# 17                                        Question 25          198
# 18                                        Question 26          193
# 19                                        Question 27          153
# 20                                        Question 28          119
# 21                                        Question 29          198
# 22                                         Question 3          117
# 23                                        Question 30          182
# 24                                         Question 4          161
# 25                                         Question 5          194
# 26                                         Question 6          196
# 27                                         Question 7          162
# 28                                         Question 8          190
# 29                                         Question 9          188
# 30  Which of the following best describes your emp...          198

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how="left", left_on="Question", right_on="Question")
print("Original dataset",len(dataset_merged))
print("dataset_merged_two: ", len(dataset_merged_two))
print("====================================================")
dataset_merged
# Out:
# Original dataset 17226
# dataset_merged_two:  17226
# ====================================================
#        Respondent ID  Custom Data 1  \
# 0         5379192392            NaN
# 1         2658722536            NaN
# 2         4044163394            NaN
# 3         5535865599            NaN
# 4         3356802928            NaN
# ...              ...            ...
# 17221     7940065082            NaN
# 17222     5157705612            NaN
# 17223     9920755555            NaN
# 17224     6638341389            NaN
# 17225     8114622230            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 17221                                  Infrastructure
# 17222                                         Finance
# 17223                                 Port Operations
# 17224                                  Infrastructure
# 17225                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17221                                                NaN
# 17222                                                NaN
# 17223                                                NaN
# 17224                                                NaN
# 17225                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17221                                    Department Lead
# 17222                                              Staff
# 17223                                              Staff
# 17224                                            Manager
# 17225                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17221          Baby Boomer (born between 1946-1964)
# 17222           Millennial (born between 1981-2000)
# 17223           Millennial (born between 1981-2000)
# 17224           Millennial (born between 1981-2000)
# 17225                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17221                                               Male
# 17222                                             Female
# 17223                                             Female
# 17224                                             Female
# 17225                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17221                                          10+ years
# 17222                                         5-10 years
# 17223                                          3-5 years
# 17224                                          3-5 years
# 17225                                         5-10 years
#
#                                   Question + Subquestion              Answer  \
# 0      Which of the following best describes your emp...  Full time Employee
# 1      Which of the following best describes your emp...  Full time Employee
# 2      Which of the following best describes your emp...  Full time Employee
# 3      Which of the following best describes your emp...  Full time Employee
# 4      Which of the following best describes your emp...  Full time Employee
# ...                                                  ...                 ...
# 17221                           Question 30 - Response 3            Answer 8
# 17222                           Question 30 - Response 3            Answer 6
# 17223                           Question 30 - Response 3                 NaN
# 17224                           Question 30 - Response 3                 NaN
# 17225                           Question 30 - Response 3                 NaN
#
#                                                 Question
# 0      Which of the following best describes your emp...
# 1      Which of the following best describes your emp...
# 2      Which of the following best describes your emp...
# 3      Which of the following best describes your emp...
# 4      Which of the following best describes your emp...
# ...                                                  ...
# 17221                                        Question 30
# 17222                                        Question 30
# 17223                                        Question 30
# 17224                                        Question 30
# 17225                                        Question 30
#
# [17226 rows x 11 columns]

# %%
same_answer = dataset_merged # [dataset_merged['Answer'].notna()]
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
same_answer.rename(columns={"Respondent ID": "Same answer"},inplace=True)
same_answer
# Out:
#                                 Question + Subquestion              Answer  \
# 0                                Question 1 - Response            Answer 1
# 1                                Question 1 - Response            Answer 2
# 2                                Question 1 - Response            Answer 3
# 3                                Question 1 - Response            Answer 4
# 4                                Question 1 - Response            Answer 5
# ..                                                 ...                 ...
# 684                            Question 9 - Response 4            Answer 5
# 685                            Question 9 - Response 4            Answer 6
# 686                            Question 9 - Response 4            Answer 7
# 687                            Question 9 - Response 4            Answer 8
# 688  Which of the following best describes your emp...  Full time Employee
#
#      Same answer
# 0             14
# 1             10
# 2             13
# 3             17
# 4             22
# ..           ...
# 684           13
# 685           14
# 686           12
# 687           19
# 688          198
#
# [689 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how="left", left_on=["Question + Subquestion", "Answer"], right_on=["Question + Subquestion", "Answer"])
print("Original dataset",len(dataset_merged_two))
print("dataset_merged_two: ", len(dataset_merged_three))
print("====================================================")
dataset_merged_three
# Out:
# Original dataset 17226
# dataset_merged_two:  17226
# ====================================================
#        Respondent ID  Custom Data 1  \
# 0         5379192392            NaN
# 1         2658722536            NaN
# 2         4044163394            NaN
# 3         5535865599            NaN
# 4         3356802928            NaN
# ...              ...            ...
# 17221     7940065082            NaN
# 17222     5157705612            NaN
# 17223     9920755555            NaN
# 17224     6638341389            NaN
# 17225     8114622230            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 17221                                  Infrastructure
# 17222                                         Finance
# 17223                                 Port Operations
# 17224                                  Infrastructure
# 17225                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17221                                                NaN
# 17222                                                NaN
# 17223                                                NaN
# 17224                                                NaN
# 17225                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17221                                    Department Lead
# 17222                                              Staff
# 17223                                              Staff
# 17224                                            Manager
# 17225                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17221          Baby Boomer (born between 1946-1964)
# 17222           Millennial (born between 1981-2000)
# 17223           Millennial (born between 1981-2000)
# 17224           Millennial (born between 1981-2000)
# 17225                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17221                                               Male
# 17222                                             Female
# 17223                                             Female
# 17224                                             Female
# 17225                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17221                                          10+ years
# 17222                                         5-10 years
# 17223                                          3-5 years
# 17224                                          3-5 years
# 17225                                         5-10 years
#
#                                   Question + Subquestion              Answer  \
# 0      Which of the following best describes your emp...  Full time Employee
# 1      Which of the following best describes your emp...  Full time Employee
# 2      Which of the following best describes your emp...  Full time Employee
# 3      Which of the following best describes your emp...  Full time Employee
# 4      Which of the following best describes your emp...  Full time Employee
# ...                                                  ...                 ...
# 17221                           Question 30 - Response 3            Answer 8
# 17222                           Question 30 - Response 3            Answer 6
# 17223                           Question 30 - Response 3                 NaN
# 17224                           Question 30 - Response 3                 NaN
# 17225                           Question 30 - Response 3                 NaN
#
#                                                 Question  Respondents  \
# 0      Which of the following best describes your emp...          198
# 1      Which of the following best describes your emp...          198
# 2      Which of the following best describes your emp...          198
# 3      Which of the following best describes your emp...          198
# 4      Which of the following best describes your emp...          198
# ...                                                  ...          ...
# 17221                                        Question 30          182
# 17222                                        Question 30          182
# 17223                                        Question 30          182
# 17224                                        Question 30          182
# 17225                                        Question 30          182
#
#        Same answer
# 0            198.0
# 1            198.0
# 2            198.0
# 3            198.0
# 4            198.0
# ...            ...
# 17221         14.0
# 17222         20.0
# 17223          NaN
# 17224          NaN
# 17225          NaN
#
# [17226 rows x 13 columns]
